# %%
n=0
while n<3:
  print("歡迎光臨，我是您的點餐機器人Amy")
  n=n+1
print("請問你的名字是?")
name=input("我的名字是")
serve=input("今天想要什麼服務呢？")
if serve=="呼叫櫃台人員":
  print("正在為您撥打電話，請稍後...")
else:
  print("我們沒有這項服務喔")
serve=("需要點餐服務嗎?")
if serve=="好":
  print("我們的餐點有:鮪魚壽司定貫、鮭魚壽司定貫、菲力牛排套餐、銀雪香煎套餐、黑松板豬套餐、嫩煎雞排套餐、什錦五蔬套餐、嫩烤羊腿套餐、鹽烤秋刀魚套餐、沙朗牛排套餐，以上套餐均附前菜（沙拉或餐包或醃漬梅）、湯（洋蔥湯或蘑菇濃湯）、甜品（紅豆麻糬或紫泥芋球）")
food="鮭魚壽司定貫"
print("我的餐點是",food)
if food=="鮭魚壽司定貫":
 print("不好意思喔!鮭魚還在海裡游抓不到，我幫您推薦點菲力牛排餐!")
else:
  print("客人您別鬧")
print("好!!!吧!")
steak=input("主人菲力牛排要幾分熟呢")
print(name,"我看您氣色不好，可以幫您前菜點沙拉好嗎?")
print("好!謝謝")
print("我們沙拉有:海鮮沙拉 生菜沙拉 雞肉沙拉")
salad="海鮮沙拉"
print("我的沙拉要,salad")
if salad=="雞肉沙拉":
  print("雞肉太老了因為是老母雞")
elif salad=="海鮮沙拉":
  print("好的沒問題!")
else:
  print("吃菜就好")
sauce=input("那主人您需要什麼醬呢?")
if sauce=="和風醬":
  print("很日式呢!")
elif sauce=="胡麻醬":
  print("很胡麻呢!")
else:
  print("阿醬沒了!沒關係吃原味就好")
soup=input("好喔主人!那湯品有洋蔥湯和蘑菇濃湯要哪一種呢?")
if soup=="洋蔥湯":
  print("不好意思洋蔥剩一點，我幫你加洋蔥圈，味道也有洋蔥味，差不多啦!")
else:
  print("好的")
dessert=input("那最後甜點有紅豆麻糬和紫泥芋球，請問要哪款呢?")
if dessert=="紫泥芋球":
  print("好的!",name,"紫泥芋球要盡快吃，不然會融化，就不好吃了!")
else:
  print("紅豆跟麻糬很搭呢")
print("了解")
print(name,"您的餐點,總共1487元")
print("期待",name,"下次光臨,您的光臨是我們的感動,啾咪!")
print("真的會感動,因為我不用再來了")

n=0
while n<3:
      print("謝謝惠顧,我是您的點餐機器人Amy")
      n=n+1
# Out:
# 歡迎光臨，我是您的點餐機器人Amy
# 歡迎光臨，我是您的點餐機器人Amy
# 歡迎光臨，我是您的點餐機器人Amy
# 請問你的名字是?
# 我的名字是佩賢
# 今天想要什麼服務呢？和主廚對話
# 我們沒有這項服務喔
# 我的餐點是 鮭魚壽司定貫
# 不好意思喔!鮭魚還在海裡游抓不到，我幫您推薦點菲力牛排餐!
# 好!!!吧!
# 主人菲力牛排要幾分熟呢五分熟
# 佩賢 我看您氣色不好，可以幫您前菜點沙拉好嗎?
# 好!謝謝
# 我們沙拉有:海鮮沙拉 生菜沙拉 雞肉沙拉
# 我的沙拉要,salad
# 好的沒問題!
# 那主人您需要什麼醬呢?凱薩醬
# 阿醬沒了!沒關係吃原味就好
# 好喔主人!那湯品有洋蔥湯和蘑菇濃湯要哪一種呢?洋蔥湯
# 不好意思洋蔥剩一點，我幫你加洋蔥圈，味道也有洋蔥味，差不多啦!
# 那最後甜點有紅豆麻糬和紫泥芋球，請問要哪款呢?紫泥芋球
# 好的! 佩賢 紫泥芋球要盡快吃，不然會融化，就不好吃了!
# 了解
# 佩賢 您的餐點,總共1487元
# 期待 佩賢 下次光臨,您的光臨是我們的感動,啾咪!
# 真的會感動,因為我不用再來了
# 謝謝惠顧,我是您的點餐機器人Amy
# 謝謝惠顧,我是您的點餐機器人Amy
# 謝謝惠顧,我是您的點餐機器人Amy
